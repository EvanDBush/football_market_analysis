# %% [markdown]
# Club Games
#
# Summary:
#     This table contains 148052 rows of game data for club teams. It contains counts of goals, home and away positions and wins. While some data like goals could be calculated from other tables it is nice to have home and away teams organized in one table.
#
#
# Insights:
#     This data could be useful to track players and clubs on a home versus away basis.
#     Another use could be to measure how league position or coach may impact results.
#     The position columns seems to contain a lot of null spaces. May not be reliable data. I suspect position may not be available for smaller leagues.
#
#     This table would be useful to determine if a clubs spending led to success in their league. Rather than tracking club position after every game, I may drop these columns and try to calculate their positions for halfway and full seasons to align with transfer windows.

# %% [markdown]
# Cleaning Tasks:
#
# drop records with no club and opponent id
# fill position columns with arbitrary high number(100) to preserve positions available and mark for easy exclusion.
# fill own goal and opponent goal columns with 0 for 24 missing games
# fill missing managers name columns with 'unavailable' to preserve names recorded and mark for exclusion.

# %%
import pandas as pd
club_games_df = pd.read_csv('../data/raw/club_games.csv')
club_games_df
# Out:
#         game_id  club_id  own_goals  own_position     own_manager_name  \
# 0       2320450   1468.0        0.0           NaN    Holger Bachthaler
# 1       2320454    222.0        0.0           NaN          Volkan Uluc
# 2       2320460      1.0        3.0           NaN      Jürgen Luginger
# 3       2320472   2036.0        4.0           NaN        Frank Schmidt
# 4       2321027     33.0        3.0           8.0          Jens Keller
# ...         ...      ...        ...           ...                  ...
# 148047  3912717     62.0        0.0           NaN  Jindrich Trpisovsky
# 148048  3912732    602.0        0.0           NaN    Vladimir Cheburin
# 148049  3912739    540.0        0.0           NaN       Vladimír Weiss
# 148050  4031421   2156.0        0.0           NaN      José Luis Oltra
# 148051  4188444   1132.0        4.0           NaN      Vincent Kompany
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# ...

# %%
club_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148052 entries, 0 to 148051
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_id                148052 non-null  int64
#  1   club_id                148034 non-null  float64
#  2   own_goals              148028 non-null  float64
#  3   own_position           103118 non-null  float64
#  4   own_manager_name       146396 non-null  object
#  5   opponent_id            148034 non-null  float64
#  6   opponent_goals         148028 non-null  float64
#  7   opponent_position      103118 non-null  float64
#  8   opponent_manager_name  146396 non-null  object
#  9   hosting                148052 non-null  object
#  10  is_win                 148052 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.4+ MB

# %%
club_games_df.describe()
# Out:
#             game_id       club_id      own_goals   own_position   opponent_id  \
# count  1.480520e+05  1.480340e+05  148028.000000  103118.000000  1.480340e+05
# mean   3.165280e+06  5.067779e+03       1.466000       9.363506  5.067779e+03
# std    6.679385e+05  3.091623e+04       1.408757       5.308675  3.091623e+04
# min    2.211607e+06  1.000000e+00       0.000000       1.000000  1.000000e+00
# 25%    2.587784e+06  3.540000e+02       0.000000       5.000000  3.540000e+02
# 50%    3.080342e+06  9.890000e+02       1.000000       9.000000  9.890000e+02
# 75%    3.646236e+06  3.060000e+03       2.000000      14.000000  3.060000e+03
# max    4.572898e+06  4.506873e+06      19.000000      21.000000  4.506873e+06
#
#        opponent_goals  opponent_position         is_win
# count   148028.000000      103118.000000  148052.000000
# mean         1.466000           9.363506       0.392808
# std          1.408757           5.308675       0.488376
# ...

# %% [markdown]
# There are 93,264 null values, primarily in the 'own_position' and 'opponent_position'. 'own_manager_name' and 'opponent_manager_name' have missing values. I will fill these columns to mantain the records we have and make these column changes easily identifiable.

# %%
club_games_df.isnull().sum()
# Out:
# game_id                      0
# club_id                     18
# own_goals                   24
# own_position             44934
# own_manager_name          1656
# opponent_id                 18
# opponent_goals              24
# opponent_position        44934
# opponent_manager_name     1656
# hosting                      0
# is_win                       0
# dtype: int64

# %%
club_games_df.duplicated().sum()
# Out:
# np.int64(0)
