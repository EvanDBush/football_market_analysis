# %% [markdown]
# Players Table
#
# Summary:
#
# This table contains 32601 rows of player data containg their name, last season, current club, country and city of birth as well as citizenship. It also contains a player's height. dominate foot, agent, contract length and more.

# %% [markdown]
# Insights:

# %% [markdown]
# Cleaning Tasks:
#
# handle 2062 missing first name
# change date_of_birth to datetime
# fill null in country_of_birth with "unavailable"
# fill null in city_of_birth with "unavailable"
# fill null in country_of_citizenship with "unavailable"
# fill null in sub-position with "none"
# fill null in foot with "unavailable"
# fill null in contract_expiration_date with empty datetime
# fill null in agent_name with 'unavailable'
# fill null in market_value_in_eur with 0
# fill null in highest_market_value in eur with 0

# %%
import pandas as pd
players_df = pd.read_csv('../data/raw/players.csv')
players_df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32601 entries, 0 to 32600
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             32601 non-null  int64
#  1   first_name                            30539 non-null  object
#  2   last_name                             32601 non-null  object
#  3   name                                  32601 non-null  object
#  4   last_season                           32601 non-null  int64
#  5   current_club_id                       32601 non-null  int64
#  6   player_code                           32601 non-null  object
#  7   country_of_birth                      29802 non-null  object
#  8   city_of_birth                         30146 non-null  object
#  9   country_of_citizenship                32218 non-null  object
#  10  date_of_birth                         32554 non-null  object
# ...

# %%
players_df.describe().round(3)
# Out:
#          player_id  last_season  current_club_id  height_in_cm  \
# count    32601.000    32601.000        32601.000     30345.000
# mean    348312.635     2019.357         4815.496       182.292
# std     284508.918        3.962        11583.708         7.037
# min         10.000     2012.000            3.000        17.000
# 25%     107973.000     2016.000          403.000       178.000
# 50%     283917.000     2020.000         1063.000       183.000
# 75%     530223.000     2023.000         3060.000       187.000
# max    1391239.000     2024.000       110302.000       210.000
#
#        market_value_in_eur  highest_market_value_in_eur
# count         3.107800e+04                 3.107800e+04
# mean          1.639685e+06                 3.789347e+06
# std           6.407293e+06                 9.887241e+06
# min           1.000000e+04                 1.000000e+04
# 25%           1.000000e+05                 2.750000e+05
# 50%           2.500000e+05                 8.000000e+05
# ...

# %%
players_df.isnull().sum()
# Out:
# player_id                                   0
# first_name                               2062
# last_name                                   0
# name                                        0
# last_season                                 0
# current_club_id                             0
# player_code                                 0
# country_of_birth                         2799
# city_of_birth                            2455
# country_of_citizenship                    383
# date_of_birth                              47
# sub_position                              180
# position                                    0
# foot                                     2536
# height_in_cm                             2256
# contract_expiration_date                12091
# agent_name                              16019
# image_url                                   0
# url                                         0
# current_club_domestic_competition_id        0
# ...

# %%
players_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
players_df['date_of_birth']
# Out:
# 0        1978-06-09 00:00:00
# 1        1980-08-06 00:00:00
# 2        1981-01-30 00:00:00
# 3        1978-05-08 00:00:00
# 4        1981-03-18 00:00:00
#                 ...
# 32596    2003-08-23 00:00:00
# 32597    2006-09-19 00:00:00
# 32598    2007-02-19 00:00:00
# 32599    2007-01-02 00:00:00
# 32600    2005-12-29 00:00:00
# Name: date_of_birth, Length: 32601, dtype: object
