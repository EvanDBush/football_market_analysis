# %% [markdown]
# Clubs Table
#
# Summary:
#     This table contains 439 rows and 17 columns and tracks data at the club team level. The data is organized by a club id and tracks the domestic league of each club. It contains information on the team like average age, squad size, market value, national team players, number of foreign players.
#
# Insights:
#     average age and market value comparisons seem interesting.

# %% [markdown]
# Cleaning Tasks:
#     calculate club market value
#         use player valuations and current club id
#     replace missing average age with domestic league average age.
#     drop url and filename columns
#     calculate missing foreigners percentage from squad size and foreigners number.

# %%
import pandas as pd 
clubs_df = pd.read_csv('../data/raw/clubs.csv')
clubs_df
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98                    SV Darmstadt 98
# 1      11127     ural-ekaterinburg                 Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 434      724           fc-volendam                        FC Volendam
# 435      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 436    85465    karpaty-lviv-2020-                    FK Karpaty Lviv
# 437      979         moreirense-fc           Moreirense Futebol Clube
# 438      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
clubs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  439 non-null    int64
#  1   club_code                439 non-null    object
#  2   name                     439 non-null    object
#  3   domestic_competition_id  439 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               439 non-null    int64
#  6   average_age              401 non-null    float64
#  7   foreigners_number        439 non-null    int64
#  8   foreigners_percentage    390 non-null    float64
#  9   national_team_players    439 non-null    int64
#  10  stadium_name             439 non-null    object
#  11  stadium_seats            439 non-null    int64
#  12  net_transfer_record      439 non-null    object
#  13  coach_name               0 non-null      float64
# ...

# %%
clubs_df.describe()
# Out:
#              club_id  total_market_value  squad_size  average_age  \
# count     439.000000                 0.0  439.000000   401.000000
# mean     6283.476082                 NaN   24.184510    25.616459
# std     14588.760049                 NaN    8.692365     2.059485
# min         3.000000                 NaN    0.000000     0.000000
# 25%       435.500000                 NaN   24.000000    24.600000
# 50%      1158.000000                 NaN   26.000000    25.800000
# 75%      3575.000000                 NaN   29.000000    26.800000
# max    110302.000000                 NaN   41.000000    29.900000
#
#        foreigners_number  foreigners_percentage  national_team_players  \
# count         439.000000             390.000000             439.000000
# mean           11.186788              46.582564               4.751708
# std             6.807645              20.274257               4.896634
# min             0.000000               2.400000               0.000000
# ...

# %%
clubs_df.isnull().sum()
# Out:
# club_id                      0
# club_code                    0
# name                         0
# domestic_competition_id      0
# total_market_value         439
# squad_size                   0
# average_age                 38
# foreigners_number            0
# foreigners_percentage       49
# national_team_players        0
# stadium_name                 0
# stadium_seats                0
# net_transfer_record          0
# coach_name                 439
# last_season                  0
# filename                     0
# url                          0
# dtype: int64

# %%
null_market_value_df = clubs_df[clubs_df['total_market_value'].isnull()]
null_market_value_df
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98                    SV Darmstadt 98
# 1      11127     ural-ekaterinburg                 Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 434      724           fc-volendam                        FC Volendam
# 435      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 436    85465    karpaty-lviv-2020-                    FK Karpaty Lviv
# 437      979         moreirense-fc           Moreirense Futebol Clube
# 438      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
clubs_df.duplicated().sum()
# Out:
# np.int64(0)
